# %%
import pandas as pd

file_path = '/Users/madhusreekalluri/Desktop/customer behaviour portfolio project/customer_shopping_behavior.csv'
df = pd.read_csv(file_path)
display(df.head())
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
display(df.describe(include='all'))
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Clothing', 'Footwear', 'Outerwear', 'Accessories'], dtype=object)

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')
display(df.columns)
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
print("Unique values in 'discount_applied':")
display(df['discount_applied'].unique())

print("\nUnique values in 'promo_code_used':")
display(df['promo_code_used'].unique())
# Out:
# Unique values in 'discount_applied':
# array(['Yes', 'No'], dtype=object)
# Unique values in 'promo_code_used':
# array(['Yes', 'No'], dtype=object)

# %%
frequency_table = pd.crosstab(df['discount_applied'], df['promo_code_used'])
display(frequency_table)
# Out:
# promo_code_used     No   Yes
# discount_applied
# No                2223     0
# Yes                  0  1677

# %%
df.drop('promo_code_used', axis=1, inplace=True)
print("Column 'promo_code_used' deleted. Updated columns:")
display(df.columns)
# Out:
# Column 'promo_code_used' deleted. Updated columns:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# ## Create Age Groups

# %%
min_age = df['age'].min()
max_age = df['age'].max()

print(f"Minimum age: {min_age}")
print(f"Maximum age: {max_age}")
# Out:
# Minimum age: 18
# Maximum age: 70

# %%
bins = [18, 26, 46, 61, 71]
labels = ['Young Adult', 'Adult', 'Mid Age', 'Senior Citizen']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

print("New 'age_group' column created.")
# Out:
# New 'age_group' column created.

# %%
display(df['age_group'].value_counts())
# Out:
# age_group
# Adult             1471
# Mid Age           1135
# Senior Citizen     723
# Young Adult        571
# Name: count, dtype: int64

# %%
frequency_mapping = {
    'Daily': 1,
    'Weekly': 7,
    'Bi-Weekly': 14,
    'Fortnightly': 14,
    'Monthly': 30,
    'Quarterly': 90,
    'Every 3 months': 90,
    'Annually': 365
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

print("Value counts for the new 'purchase_frequency_days' column:")
print(df['purchase_frequency_days'].value_counts())
print("\nFirst 5 rows with 'frequency_of_purchases' and 'purchase_frequency_days' columns:")
print(df[['frequency_of_purchases', 'purchase_frequency_days']].head())
# Out:
# Value counts for the new 'purchase_frequency_days' column:
# purchase_frequency_days
# 14.0     1089
# 365.0     572
# 90.0      563
# 30.0      553
# 7.0       539
# Name: count, dtype: int64
#
# First 5 rows with 'frequency_of_purchases' and 'purchase_frequency_days' columns:
#   frequency_of_purchases  purchase_frequency_days
# 0            Fortnightly                     14.0
# 1            Fortnightly                     14.0
# 2                 Weekly                      7.0
# 3                 Weekly                      7.0
# 4               Annually                    365.0

# %%
df['frequency_of_purchases_days'] = df['frequency_of_purchases'].map(frequency_mapping)
print("Converted 'frequency_of_purchases' to numerical days.")
display(df.head())
df.info()
# Out:
# Converted 'frequency_of_purchases' to numerical days.
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
print("Unique values in 'frequency_of_purchases':")
display(df['frequency_of_purchases'].unique())
print("\nData type of 'frequency_of_purchases':")
display(df['frequency_of_purchases'].dtype)
# Out:
# Unique values in 'frequency_of_purchases':
# array(['Fortnightly', 'Weekly', 'Annually', 'Quarterly', 'Bi-Weekly',
#        'Monthly', 'Every 3 Months'], dtype=object)
# Data type of 'frequency_of_purchases':
# dtype('O')

# %%
import pandas as pd

file_path = '/Users/madhusreekalluri/Desktop/customer behaviour portfolio project/customer_shopping_behavior.csv'
df = pd.read_csv(file_path)
display(df.head())
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')
display(df.columns)
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df.drop('promo_code_used', axis=1, inplace=True)
print("Column 'promo_code_used' deleted. Updated columns:")
display(df.columns)
# Out:
# Column 'promo_code_used' deleted. Updated columns:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
bins = [18, 26, 46, 61, 71]
labels = ['Young Adult', 'Adult', 'Mid Age', 'Senior Citizen']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

print("New 'age_group' column created.")
display(df['age_group'].value_counts())
# Out:
# New 'age_group' column created.
# age_group
# Adult             1471
# Mid Age           1135
# Senior Citizen     723
# Young Adult        571
# Name: count, dtype: int64

# %%
df['frequency_of_purchases_days'] = df['frequency_of_purchases'].map(frequency_mapping)
print("Converted 'frequency_of_purchases' to numerical days.")
display(df.head())
df.info()
# Out:
# Converted 'frequency_of_purchases' to numerical days.
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df['frequency_of_purchases_days'] = df['frequency_of_purchases_days'].astype('Int64')

print(df['frequency_of_purchases_days'].dtype)
# Out:
# Int64

# %%
display(df.head(10))
df.info()
# Out:
#    customer_id  age gender item_purchased     category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         location size      color  season  review_rating subscription_status  \
# ...

# %%
df = df.drop(columns=['frequency_of_purchases'])

# %%
df.head(10)
# Out:
#    customer_id  age gender item_purchased     category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         location size      color  season  review_rating subscription_status  \
# ...

# %%
# %pip install sqlalchemy pymysql pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, text
import urllib.parse

user = "root"
password = "Madhusree@20"
host = "localhost"
port = "3306"
db_name = "customer_analysis"

safe_password = urllib.parse.quote_plus(password)
url = f"mysql+pymysql://{user}:{safe_password}@{host}:{port}"

try:
    engine = create_engine(url)
    with engine.connect() as conn:
        conn.execute(text(f"CREATE DATABASE IF NOT EXISTS {db_name}"))
        conn.execute(text("COMMIT"))
    
    db_url = f"{url}/{db_name}"
    db_engine = create_engine(db_url)
    
    df_sql = df.copy()
    for col in df_sql.columns:
        if str(df_sql[col].dtype) in ['category', 'Int64', 'object', 'category']:
            df_sql[col] = df_sql[col].astype(str)
            
    df_sql.to_sql('shopping_data', con=db_engine, if_exists='replace', index=False)
    print("DONE! Check your MySQL tab now.")
except NameError:
    print("Please click 'Run All' at the top of the page first!")
except Exception as e:
    print(e)
# Out:
# DONE! Check your MySQL tab now.
